# %%
import csv
import re
path = '160602_A_T.txt'

# %%
f = open(path, 'rb')
reader = csv.reader(f)
data = []
for line in reader:
    data.append(line[0])

# %%
data[0]
# Out:
# '2700\t63.2292\t55.6637\t45.10845\t34.20983\t29.27258\t34.11481\t47.51308\t57.69962\t66.07945\t76.15271\t59.66612\t55.52158\t41.69572\t31.53149\t29.10954\t31.64678\t39.14354\t51.71163\t65.09613\t77.72331\t59.40515\t50.50714\t46.86268\t32.48398\t28.48134\t30.46412\t34.40335\t40.89379\t57.9869\t64.92818\t59.37312\t51.82637\t41.51515\t34.45301\t30.89003\t32.3259\t34.13077\t35.97883\t45.74465\t53.36211\t57.50124\t51.5235\t41.22819\t35.14011\t29.71333\t30.64438\t27.7789\t30.20182\t35.63034\t44.69401\t57.906\t48.49635\t44.12737\t34.21452\t29.14262\t26.50021\t24.88421\t27.34009\t38.06911\t36.15834\t57.58994\t53.03592\t50.88797\t34.30972\t36.54702\t27.66041\t32.88601\t29.48025\t34.56041\t33.91713\t58.92675\t48.14113\t43.18838\t41.51565\t36.57814\t34.77819\t30.25454\t24.8177\t29.60478\t36.26591\t55.00422\t53.50212\t46.17852\t48.30707\t39.67379\t35.02355\t37.71878\t34.61877\t38.68916\t32.13466\t58.2134\t57.60596\t53.3227\t54.52568\t48.86676\t50.1334\t42.76128\t41.48606\t39.0738\t41.57684'

# %%
re.split(r'\t+', data[0])
# Out:
# ['2700',
#  '63.2292',
#  '55.6637',
#  '45.10845',
#  '34.20983',
#  '29.27258',
#  '34.11481',
#  '47.51308',
#  '57.69962',
#  '66.07945',
#  '76.15271',
#  '59.66612',
#  '55.52158',
#  '41.69572',
#  '31.53149',
#  '29.10954',
#  '31.64678',
#  '39.14354',
#  '51.71163',
#  '65.09613',
#  '77.72331',
#  '59.40515',
#  '50.50714',
#  '46.86268',
#  '32.48398',
#  '28.48134',
#  '30.46412',
#  '34.40335',
#  '40.89379',
#  '57.9869',
#  '64.92818',
#  '59.37312',
#  '51.82637',
#  '41.51515',
#  '34.45301',
#  '30.89003',
#  '32.3259',
#  '34.13077',
#  '35.97883',
#  '45.74465',
#  '53.36211',
#  '57.50124',
#  '51.5235',
#  '41.22819',
#  '35.14011',
#  '29.71333',
#  '30.64438',
#  '27.7789',
#  '30.20182',
#  '35.63034',
#  '44.69401',
#  '57.906',
#  '48.49635',
#  '44.12737',
#  '34.21452',
#  '29.14262',
#  '26.50021',
#  '24.88421',
#  '27.34009',
#  '38.06911',
#  '36.15834',
#  '57.58994',
#  '53.03592',
#  '50.88797',
#  '34.30972',
#  '36.54702',
#  '27.66041',
# ...
