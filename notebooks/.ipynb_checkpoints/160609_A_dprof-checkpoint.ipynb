# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import os
import sys
import csv
scripts_path = os.path.abspath(os.path.join('../scripts/'))
data_path = os.path.abspath(os.path.join('../data/'))
sys.path.append(scripts_path)
sys.path.append(data_path)

# %%
scripts_path
# Out:
# '/home/treharne/Documents/projects/SAZO/scripts'

# %%
path = data_path + '/T/160602_A_extract_d.txt'

# %%
path
# Out:
# '/home/treharne/Documents/projects/SAZO/data/T/160602_A_extract_d.txt'

# %%
f = open(path, 'rb')
reader = csv.reader(f)
data = []
for line in reader:
    #nice and pythonic here
    data.append([float(x) for x in line[0].split(' ')])

# %%
len(data)
# Out:
# 100

# %%
trans_data = np.transpose(data)

# %%
x = []
y = []
for i in range(0, 10):
    if i % 2 == 0:
        for j in range(0, 10):
            x.append((j-4.5)*10)
            y.append((4.5-i)*10)
    else:
        for j in range(0, 10):
            x.append((4.5 - j)*10)
            y.append((4.5-i)*10)
            
z = trans_data[2]
plasma = trans_data[3]

# %%
darray = x,y,z
parray = x,y,plasma

# %%
xi = np.linspace(min(x), max(x), 100)
yi = np.linspace(min(y), max(y), 100)

# %%
zi = griddata(x, y, z, xi, yi)
plasmai = griddata(x,y,plasma,xi,yi)

# %%
# %pylab inline
fig = figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.set_aspect('equal')

S = ax.contour(xi, yi, zi, 10, colors='k')
CF = ax.contourf(xi, yi, zi, 50, cmap='gist_rainbow')
ax.clabel(S, fontsize=15, fmt='%1.2f')

ax.set_xlabel('x (mm)', fontsize=15)
ax.set_ylabel('y (mm)', fontsize=15)
ax.tick_params(labelsize=15)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
rs_path = data_path + '/4PP/160602_A.dat'

# %%
rs_path
# Out:
# '/home/treharne/Documents/projects/SAZO/data/4PP/160602_A.dat'

# %%
import rs_contour as cont

# %%
rs = cont.get_data(rs_path)

# %%
def sortthis(array):
    sort1 = sorted(array, key=lambda x: x[0])
    sort2 = sorted(sort1, key=lambda x: x[1])
    
    return sort2

# %%
A = sortthis(np.transpose(darray))
B = sortthis(np.transpose(rs))
D = sortthis(np.transpose(parray))

rho =(transpose(A)[2]*transpose(B)[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-9a094db95077> in <module>()
#       3 D = sortthis(np.transpose(parray))
#       4
# ----> 5 rho =(transpose(A)[2]*transpose(B)[2])
#       6
#       7
#
# ValueError: operands could not be broadcast together with shapes (100,) (99,)

# %%
def formatthis(array):
    x = array[0]
    y = array[1]
    z = array[2]

    xi = np.linspace(min(x), max(x), 10)
    yi = np.linspace(min(y), max(y), 10)
    zi = griddata(x, y, z, xi, yi)
    
    return xi, yi, zi

# %%
Ai = formatthis(np.transpose(A))
Bi = formatthis(np.transpose(B))
Ci = (Ai[2]*Bi[2]*4.532*1e-7)
Di = (formatthis(np.transpose(D))[2]).ravel()
di = Ai[2].ravel()

# %%
mobi = (1/(Ci*Di)).ravel()

# %%
#plot of resistivity 
#NB. not real. mixed data from two similar samples
#4PP from 160602, d-prof from 160601
fig = figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.set_aspect('equal')

S = ax.contour(Ai[0], Ai[1], mobi, 10, colors='k')
CF = ax.contourf(Ai[0], Ai[1], mobi, 50, cmap='gist_rainbow')
ax.clabel(S, fontsize=15, fmt='%1.2f')
# Out:
# <a list of 14 text.Text objects>

# %%
scatter(Di, mobi, c=di)
